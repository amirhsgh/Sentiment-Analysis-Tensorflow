# %%
import os
from nltk.corpus import stopwords
from nltk import word_tokenize
from string import punctuation
import random

# %%
stop_words = stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
import pandas as pd

# %%
df = pd.read_csv("IMDB Dataset.csv")

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
negative_documents = []
max_len_negative = 0
positive_documents = []
max_len_positive = 0
for ind, row in df.iterrows():
    if row['sentiment']=="negative":
        text = row['review']
        tokens = word_tokenize(text)
        translator = str.maketrans('', '', punctuation)
        tokens = [w.translate(translator) for w in tokens]
        tokens = [w for w in tokens if not w in stop_words]
        if len(tokens) > max_len_negative:
            max_len_negative = len(tokens)
        negative_documents.append(' '.join(tokens))
    else:
        text = row['review']
        tokens = word_tokenize(text)
        translator = str.maketrans('', '', punctuation)
        tokens = [w.translate(translator) for w in tokens]
        tokens = [w for w in tokens if not w in stop_words]
        if len(tokens) > max_len_positive:
            max_len_positive = len(tokens)
        positive_documents.append(' '.join(tokens))

# %%
len(negative_documents)
# Out:
# 25000

# %%
len(positive_documents)
# Out:
# 25000

# %%
max_len_negative
# Out:
# 1287

# %%
max_len_positive
# Out:
# 1824

# %%
max_len = max(max_len_negative, max_len_positive)

# %%
random.shuffle(negative_documents)
random.shuffle(positive_documents)

# %%
X_train = negative_documents[:20000] + positive_documents[:20000]

# %%
len(X_train)
# Out:
# 40000

# %%
y_train = [0 for _ in range(20000)] + [1 for _ in range(20000)]

# %%
len(y_train)
# Out:
# 40000

# %%
X_test = negative_documents[20000:] + positive_documents[20000:]
len(X_test)
# Out:
# 10000

# %%
y_test = [0 for _ in range(5000)] + [1 for _ in range(5000)]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Embedding, Conv1D, MaxPool1D, Dropout
from tensorflow.keras.layers import concatenate

# %%
max_len
# Out:
# 1824

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
import pickle
with open('tokenizer.h5', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
tokenizer

# %%
vocab_len = len(tokenizer.word_index) + 1

# %%
vocab_len
# Out:
# 123623

# %%
encoded = tokenizer.texts_to_sequences(X_train)

# %%
encoded[0]
# Out:
# [108,
#  5,
#  1796,
#  15,
#  21,
#  462,
#  2815,
#  477,
#  9736,
#  9737,
#  675,
#  4072,
#  19953,
#  79,
#  394,
#  7236,
#  3118,
#  4,
#  2018,
#  1625,
#  565,
#  336,
#  101,
#  349,
#  772,
#  109,
#  232,
#  3933,
#  83,
#  4072,
#  12574,
#  4179,
#  599,
#  1,
#  1,
#  1580,
#  152,
#  1641,
#  2,
#  202,
#  2,
#  2313,
#  24,
#  2177,
#  8448,
#  316,
#  124,
#  15,
#  11,
#  99,
#  195,
#  67]

# %%
padded = pad_sequences(encoded, maxlen=max_len, padding='post')

# %%
padded.shape
# Out:
# (40000, 1824)

# %%
input1 = Input(shape=(max_len,))
embedding1 = Embedding(vocab_len, 100)(input1)
conv1 = Conv1D(filters=32, kernel_size=4, activation='relu')(embedding1)
drop1 = Dropout(0.5)(conv1)
pool1 = MaxPool1D(pool_size=2)(drop1)
flat1 = Flatten()(pool1)
dense1 = Dense(10, activation='relu')(flat1)
output = Dense(1, activation='sigmoid')(dense1)

# %%
model = Model(inputs=[input1], outputs=output)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1824)]            0
#
#  embedding_1 (Embedding)     (None, 1824, 100)         12362300
#
#  conv1d_1 (Conv1D)           (None, 1821, 32)          12832
#
#  dropout_1 (Dropout)         (None, 1821, 32)          0
#
#  max_pooling1d_1 (MaxPooling  (None, 910, 32)          0
#  1D)
#
#  flatten_1 (Flatten)         (None, 29120)             0
#
#  dense_2 (Dense)             (None, 10)                291210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 12,666,353
# Trainable params: 12,666,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoded_test = tokenizer.texts_to_sequences(X_test)
padded_test = pad_sequences(encoded_test, maxlen=max_len, padding='post')

# %%
padded_test.shape
# Out:
# (10000, 1824)

# %%
import numpy as np

# %%
model.fit([padded], np.array(y_train), epochs=50, batch_size=20, validation_data=([padded_test], np.array(y_test)))
# Out:
# Epoch 1/50
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.7298 - val_accuracy: 0.8808
# Epoch 2/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.6996 - val_accuracy: 0.8827
# Epoch 3/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.8774 - val_accuracy: 0.8812
# Epoch 4/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.8955 - val_accuracy: 0.8796
# Epoch 5/50
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.8721 - val_accuracy: 0.8742
# Epoch 6/50
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.8412 - val_accuracy: 0.8836
# Epoch 7/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.9929 - val_accuracy: 0.8844
# Epoch 8/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.0440 - val_accuracy: 0.8830
# Epoch 9/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.9768 - val_accuracy: 0.8802
# Epoch 10/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.8178 - val_accuracy: 0.8821
# Epoch 11/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.7677 - val_accuracy: 0.8846
# Epoch 12/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.7915 - val_accuracy: 0.8853
# Epoch 13/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.8565 - val_accuracy: 0.8842
# Epoch 14/50
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 1.0071 - val_accuracy: 0.8855
# Epoch 15/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.9414 - val_accuracy: 0.8814
# Epoch 16/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.8423 - val_accuracy: 0.8837
# Epoch 17/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.9205 - val_accuracy: 0.8849
# Epoch 18/50
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.6998 - val_accuracy: 0.8810
# Epoch 19/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.8903 - val_accuracy: 0.8840
# Epoch 20/50
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.9166 - val_accuracy: 0.8820
# Epoch 21/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 8.7125e-04 - accuracy: 0.9998 - val_loss: 1.1052 - val_accuracy: 0.8821
# Epoch 22/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 1.2275 - val_accuracy: 0.8827
# Epoch 23/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 1.1836 - val_accuracy: 0.8806
# Epoch 24/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 1.2077 - val_accuracy: 0.8828
# Epoch 25/50
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.8153 - val_accuracy: 0.8863
# Epoch 26/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.9965 - val_accuracy: 0.8849
# Epoch 27/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 6.2483e-04 - accuracy: 0.9998 - val_loss: 1.2552 - val_accuracy: 0.8808
# Epoch 28/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 1.0801 - val_accuracy: 0.8836
# Epoch 29/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 1.0585 - val_accuracy: 0.8827
# Epoch 30/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 1.0748 - val_accuracy: 0.8836
# Epoch 31/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 9.8712e-04 - accuracy: 0.9997 - val_loss: 1.0899 - val_accuracy: 0.8833
# Epoch 32/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 1.1671 - val_accuracy: 0.8824
# Epoch 33/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 6.4646e-04 - accuracy: 0.9997 - val_loss: 1.4558 - val_accuracy: 0.8711
# Epoch 34/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 1.3269 - val_accuracy: 0.8841
# Epoch 35/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 1.5082 - val_accuracy: 0.8819
# Epoch 36/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 1.1030 - val_accuracy: 0.8842
# Epoch 37/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 4.2355e-04 - accuracy: 0.9998 - val_loss: 1.3353 - val_accuracy: 0.8855
# Epoch 38/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 1.2701 - val_accuracy: 0.8805
# Epoch 39/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 1.2333 - val_accuracy: 0.8870
# Epoch 40/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 6.8782e-04 - accuracy: 0.9998 - val_loss: 1.5727 - val_accuracy: 0.8842
# Epoch 41/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 9.2321e-04 - accuracy: 0.9998 - val_loss: 1.6330 - val_accuracy: 0.8851
# Epoch 42/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 1.4345 - val_accuracy: 0.8823
# Epoch 43/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 1.3516 - val_accuracy: 0.8820
# Epoch 44/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 1.0552 - val_accuracy: 0.8834
# Epoch 45/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 7.2332e-04 - accuracy: 0.9997 - val_loss: 1.2396 - val_accuracy: 0.8817
# Epoch 46/50
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 1.1718 - val_accuracy: 0.8839
# Epoch 47/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 3.4496e-05 - accuracy: 1.0000 - val_loss: 1.3597 - val_accuracy: 0.8837
# Epoch 48/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 2.9274e-05 - accuracy: 1.0000 - val_loss: 1.6756 - val_accuracy: 0.8833
# Epoch 49/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 1.7711 - val_accuracy: 0.8823
# Epoch 50/50
# 2000/2000 [==============================] - 18s 9ms/step - loss: 7.3407e-04 - accuracy: 0.9999 - val_loss: 1.7023 - val_accuracy: 0.8818

# %%
model.save('textcnn.h5')

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('textcnn.h5')

# %%
with open('tokenizer.h5', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
tokenizer.word_index
# Out:
# {'br': 1,
#  'i': 2,
#  'the': 3,
#  'movie': 4,
#  'film': 5,
#  'nt': 6,
#  'one': 7,
#  'like': 8,
#  'it': 9,
#  'this': 10,
#  'good': 11,
#  'would': 12,
#  'even': 13,
#  'time': 14,
#  'really': 15,
#  'story': 16,
#  'see': 17,
#  'well': 18,
#  'much': 19,
#  'could': 20,
#  'get': 21,
#  'bad': 22,
#  'people': 23,
#  'great': 24,
#  'also': 25,
#  'first': 26,
#  'made': 27,
#  'way': 28,
#  'make': 29,
#  'movies': 30,
#  'but': 31,
#  'characters': 32,
#  'think': 33,
#  'and': 34,
#  'watch': 35,
#  'films': 36,
#  'character': 37,
#  'many': 38,
#  'seen': 39,
#  'two': 40,
#  'never': 41,
#  'acting': 42,
#  'love': 43,
#  'plot': 44,
#  'best': 45,
#  'show': 46,
#  'know': 47,
#  'little': 48,
#  'a': 49,
#  'life': 50,
#  'in': 51,
#  'there': 52,
#  'ever': 53,
#  'better': 54,
#  'man': 55,
#  'end': 56,
#  'if': 57,
#  'scene': 58,
#  'still': 59,
#  'say': 60,
#  'he': 61,
#  'scenes': 62,
#  'something': 63,
#  'go': 64,
#  'back': 65,
#  'thing': 66,
#  'watching': 67,
#  'real': 68,
#  'though': 69,
#  'actors': 70,
#  'years': 71,
#  'funny': 72,
#  'actually': 73,
#  'another': 74,
#  'work': 75,
#  'makes': 76,
#  'nothing': 77,
#  'find': 78,
#  'director': 79,
#  'look': 80,
#  'going': 81,
#  'new': 82,
#  'lot': 83,
#  'every': 84,
#  'us': 85,
#  'old': 86,
#  'part': 87,
#  'things': 88,
#  'want': 89,
#  'world': 90,
#  'cast': 91,
#  'pretty': 92,
#  'quite': 93,
#  'got': 94,
#  'around': 95,
#  'ca': 96,
#  'young': 97,
#  'seems': 98,
#  'enough': 99,
#  'you': 100,
#  'however': 101,
#  'fact': 102,
#  'take': 103,
#  'horror': 104,
#  'thought': 105,
#  'give': 106,
#  'may': 107,
#  'what': 108,
#  'big': 109,
#  'as': 110,
#  'they': 111,
#  'without': 112,
#  'long': 113,
#  'times': 114,
#  'right': 115,
#  'music': 116,
#  'saw': 117,
#  'original': 118,
#  'guy': 119,
#  'must': 120,
#  'always': 121,
#  'comedy': 122,
#  'almost': 123,
#  'role': 124,
#  'series': 125,
#  'come': 126,
#  'gets': 127,
#  'interesting': 128,
#  'action': 129,
#  'point': 130,
#  'least': 131,
#  'whole': 132,
#  'minutes': 133,
#  'done': 134,
#  'bit': 135,
#  'script': 136,
#  'far': 137,
#  'anything': 138,
#  'feel': 139,
#  'might': 140,
#  'since': 141,
#  'family': 142,
#  'last': 143,
#  'probably': 144,
#  'tv': 145,
#  'performance': 146,
#  'that': 147,
#  'so': 148,
#  'kind': 149,
#  'away': 150,
#  'yet': 151,
#  'anyone': 152,
#  'she': 153,
#  'sure': 154,
#  'woman': 155,
#  'rather': 156,
#  'worst': 157,
#  'not': 158,
#  'girl': 159,
#  'fun': 160,
#  'played': 161,
#  'found': 162,
#  'making': 163,
#  'believe': 164,
#  'although': 165,
#  'day': 166,
#  'especially': 167,
#  'trying': 168,
#  'when': 169,
#  'course': 170,
#  'everything': 171,
#  'comes': 172,
#  'dvd': 173,
#  'hard': 174,
#  'goes': 175,
#  'different': 176,
#  'shows': 177,
#  'maybe': 178,
#  'ending': 179,
#  'place': 180,
#  'put': 181,
#  'someone': 182,
#  'worth': 183,
#  'let': 184,
#  'book': 185,
#  'screen': 186,
#  'main': 187,
#  'looking': 188,
#  'actor': 189,
#  '2': 190,
#  'sense': 191,
#  'play': 192,
#  'set': 193,
#  'looks': 194,
#  'reason': 195,
#  'everyone': 196,
#  'effects': 197,
#  'money': 198,
#  'true': 199,
#  '10': 200,
#  'three': 201,
#  'watched': 202,
#  'all': 203,
#  'job': 204,
#  'plays': 205,
#  'instead': 206,
#  'together': 207,
#  'audience': 208,
#  'said': 209,
#  'for': 210,
#  'john': 211,
#  'later': 212,
#  'takes': 213,
#  'beautiful': 214,
#  'seem': 215,
#  'my': 216,
#  'special': 217,
#  'seeing': 218,
#  'american': 219,
#  'left': 220,
#  'night': 221,
#  'war': 222,
#  'version': 223,
#  'we': 224,
#  'excellent': 225,
#  'idea': 226,
#  'else': 227,
#  'shot': 228,
#  'completely': 229,
#  'death': 230,
#  'wife': 231,
#  'fan': 232,
#  'nice': 233,
#  'house': 234,
#  'high': 235,
#  'simply': 236,
#  'along': 237,
#  'black': 238,
#  'poor': 239,
#  'read': 240,
#  'men': 241,
#  'mind': 242,
#  'used': 243,
#  'father': 244,
#  'star': 245,
#  'short': 246,
#  'help': 247,
#  'year': 248,
#  'second': 249,
#  'boring': 250,
#  'either': 251,
#  'less': 252,
#  'need': 253,
#  'do': 254,
#  'use': 255,
#  'kids': 256,
#  'home': 257,
#  'enjoy': 258,
#  'half': 259,
#  'no': 260,
#  'try': 261,
#  'hollywood': 262,
#  'given': 263,
#  'production': 264,
#  'friends': 265,
#  'classic': 266,
#  'wrong': 267,
#  'women': 268,
#  'dead': 269,
#  'performances': 270,
#  'to': 271,
#  'stupid': 272,
#  'couple': 273,
#  'recommend': 274,
#  'next': 275,
#  'line': 276,
#  'rest': 277,
#  'truly': 278,
#  'start': 279,
#  'of': 280,
#  'came': 281,
#  'understand': 282,
#  'getting': 283,
#  'terrible': 284,
#  'tell': 285,
#  'full': 286,
#  'school': 287,
#  'awful': 288,
#  'perhaps': 289,
#  'remember': 290,
#  'at': 291,
#  'camera': 292,
#  'moments': 293,
#  'sex': 294,
#  'mean': 295,
#  'person': 296,
#  'keep': 297,
#  'video': 298,
#  'wonderful': 299,
#  'definitely': 300,
#  'others': 301,
#  'name': 302,
#  'budget': 303,
#  'after': 304,
#  'episode': 305,
#  'playing': 306,
#  'often': 307,
#  'face': 308,
#  'perfect': 309,
#  'top': 310,
#  'small': 311,
#  'mother': 312,
#  'human': 313,
#  'gives': 314,
#  'children': 315,
#  'early': 316,
#  'lines': 317,
#  'dialogue': 318,
#  'piece': 319,
#  'went': 320,
#  'finally': 321,
#  'certainly': 322,
#  'yes': 323,
#  'case': 324,
#  'stars': 325,
#  'title': 326,
#  'lost': 327,
#  'boy': 328,
#  'hope': 329,
#  'absolutely': 330,
#  'head': 331,
#  'sort': 332,
#  'worse': 333,
#  'liked': 334,
#  'become': 335,
#  'style': 336,
#  'friend': 337,
#  'several': 338,
#  'picture': 339,
#  'entertaining': 340,
#  'written': 341,
#  'oh': 342,
#  'guys': 343,
#  'cinema': 344,
#  'supposed': 345,
#  'overall': 346,
#  'entire': 347,
#  '3': 348,
#  'problem': 349,
#  'loved': 350,
#  'felt': 351,
#  'live': 352,
#  'his': 353,
#  'laugh': 354,
#  'based': 355,
#  'waste': 356,
#  'then': 357,
#  'mr': 358,
#  'sound': 359,
#  'care': 360,
#  'totally': 361,
#  'beginning': 362,
#  'dark': 363,
#  '1': 364,
#  'humor': 365,
#  'direction': 366,
#  'fans': 367,
#  'drama': 368,
#  'despite': 369,
#  'evil': 370,
#  'final': 371,
#  'why': 372,
#  'while': 373,
#  'guess': 374,
#  'example': 375,
#  'game': 376,
#  'seemed': 377,
#  'lives': 378,
#  'lead': 379,
#  'wanted': 380,
#  'already': 381,
#  'called': 382,
#  'throughout': 383,
#  'now': 384,
#  'low': 385,
#  'turn': 386,
#  'becomes': 387,
#  'able': 388,
#  'history': 389,
#  'unfortunately': 390,
#  'killer': 391,
#  'some': 392,
#  'wants': 393,
#  'michael': 394,
#  'horrible': 395,
#  'days': 396,
#  'fine': 397,
#  'quality': 398,
#  'today': 399,
#  'white': 400,
#  'son': 401,
#  '\x96': 402,
#  'writing': 403,
#  'works': 404,
#  'tries': 405,
#  'enjoyed': 406,
#  'flick': 407,
#  'etc': 408,
#  'amazing': 409,
#  'with': 410,
#  'wo': 411,
#  'act': 412,
#  'how': 413,
#  'kill': 414,
#  'town': 415,
#  'gave': 416,
#  'side': 417,
#  'eyes': 418,
#  'viewer': 419,
#  'parts': 420,
#  'past': 421,
#  'turns': 422,
#  'matter': 423,
#  'expect': 424,
#  'girls': 425,
#  'favorite': 426,
#  'child': 427,
#  'car': 428,
#  'killed': 429,
#  'stuff': 430,
#  'obviously': 431,
#  'city': 432,
#  'behind': 433,
#  'brilliant': 434,
#  'kid': 435,
#  'god': 436,
#  'genre': 437,
#  'run': 438,
#  'directed': 439,
#  'heart': 440,
#  'starts': 441,
#  'sometimes': 442,
#  'late': 443,
#  'thinking': 444,
#  'soon': 445,
#  'art': 446,
#  'actress': 447,
#  'decent': 448,
#  'took': 449,
#  'says': 450,
#  'on': 451,
#  'heard': 452,
#  'just': 453,
#  'group': 454,
#  'except': 455,
#  'anyway': 456,
#  'daughter': 457,
#  'happens': 458,
#  'highly': 459,
#  'blood': 460,
#  'experience': 461,
#  'feeling': 462,
#  'score': 463,
#  'stories': 464,
#  'close': 465,
#  'coming': 466,
#  'fight': 467,
#  'lack': 468,
#  'extremely': 469,
#  'ok': 470,
#  'is': 471,
#  'wonder': 472,
#  'leave': 473,
#  'roles': 474,
#  'police': 475,
#  'moment': 476,
#  'james': 477,
#  'including': 478,
#  'hour': 479,
#  'type': 480,
#  'save': 481,
#  'david': 482,
#  'chance': 483,
#  'told': 484,
#  'happen': 485,
#  'involved': 486,
#  'hand': 487,
#  'hilarious': 488,
#  'cool': 489,
#  'violence': 490,
#  'happened': 491,
#  'serious': 492,
#  'looked': 493,
#  'strong': 494,
#  'simple': 495,
#  'living': 496,
#  'hell': 497,
#  'voice': 498,
#  'complete': 499,
#  'seriously': 500,
#  'taken': 501,
#  'stop': 502,
#  'attempt': 503,
#  'robert': 504,
#  'crap': 505,
#  'song': 506,
#  'hero': 507,
#  'particularly': 508,
#  'ago': 509,
#  'across': 510,
#  'shown': 511,
#  'released': 512,
#  'obvious': 513,
#  'murder': 514,
#  'please': 515,
#  'exactly': 516,
#  'slow': 517,
#  'interest': 518,
#  'reality': 519,
#  'usually': 520,
#  'brother': 521,
#  'opening': 522,
#  'possible': 523,
#  'saying': 524,
#  'sad': 525,
#  'english': 526,
#  'none': 527,
#  'alone': 528,
#  'relationship': 529,
#  'cinematography': 530,
#  'huge': 531,
#  'known': 532,
#  'cut': 533,
#  'number': 534,
#  'gore': 535,
#  'career': 536,
#  'wish': 537,
#  'whose': 538,
#  'shots': 539,
#  'age': 540,
#  'husband': 541,
#  'annoying': 542,
#  'hours': 543,
#  'order': 544,
#  '5': 545,
#  'talent': 546,
#  '4': 547,
#  'hit': 548,
#  'running': 549,
#  'call': 550,
#  'ends': 551,
#  'jokes': 552,
#  'usual': 553,
#  'major': 554,
#  'mostly': 555,
#  'body': 556,
#  'opinion': 557,
#  'ridiculous': 558,
#  'started': 559,
#  'view': 560,
#  'country': 561,
#  'novel': 562,
#  'change': 563,
#  'power': 564,
#  'documentary': 565,
#  'ones': 566,
#  'scary': 567,
#  'somewhat': 568,
#  'beyond': 569,
#  'important': 570,
#  'silly': 571,
#  'disappointed': 572,
#  'taking': 573,
#  'strange': 574,
#  'level': 575,
#  'turned': 576,
#  'finds': 577,
#  'apparently': 578,
#  'words': 579,
#  'upon': 580,
#  'female': 581,
#  'basically': 582,
#  'talking': 583,
#  'knows': 584,
#  'four': 585,
#  'word': 586,
#  'knew': 587,
#  'clearly': 588,
#  'room': 589,
#  'from': 590,
#  'due': 591,
#  'problems': 592,
#  'rating': 593,
#  'musical': 594,
#  'happy': 595,
#  'sequence': 596,
#  'jack': 597,
#  'episodes': 598,
#  'attention': 599,
#  'single': 600,
#  'george': 601,
#  'talk': 602,
#  'king': 603,
#  'cheap': 604,
#  'predictable': 605,
#  'local': 606,
#  'miss': 607,
#  'television': 608,
#  'modern': 609,
#  'events': 610,
#  'sets': 611,
#  'british': 612,
#  'tells': 613,
#  'whether': 614,
#  'french': 615,
#  'light': 616,
#  'review': 617,
#  'earth': 618,
#  'add': 619,
#  'entertainment': 620,
#  'team': 621,
#  'easily': 622,
#  'appears': 623,
#  'dialog': 624,
#  'soundtrack': 625,
#  'writer': 626,
#  'songs': 627,
#  'giving': 628,
#  'future': 629,
#  'enjoyable': 630,
#  'moving': 631,
#  'ten': 632,
#  'space': 633,
#  'mention': 634,
#  'bring': 635,
#  'supporting': 636,
#  'needs': 637,
#  'message': 638,
#  'similar': 639,
#  'clear': 640,
#  'falls': 641,
#  'tried': 642,
#  'romantic': 643,
#  'within': 644,
#  'bunch': 645,
#  'storyline': 646,
#  'showing': 647,
#  'sequel': 648,
#  'lots': 649,
#  'surprised': 650,
#  'filmed': 651,
#  'easy': 652,
#  'ways': 653,
#  'five': 654,
#  'theater': 655,
#  'dull': 656,
#  'stay': 657,
#  'sorry': 658,
#  'release': 659,
#  'certain': 660,
#  'parents': 661,
#  'who': 662,
#  'hate': 663,
#  'suspense': 664,
#  'middle': 665,
#  'among': 666,
#  'comments': 667,
#  'theme': 668,
#  'fall': 669,
#  'peter': 670,
#  'richard': 671,
#  'editing': 672,
#  'doubt': 673,
#  'viewing': 674,
#  'subject': 675,
#  'thriller': 676,
#  'comic': 677,
#  'actual': 678,
#  'gone': 679,
#  'buy': 680,
#  'effort': 681,
#  'an': 682,
#  'die': 683,
#  'sister': 684,
#  'named': 685,
#  'typical': 686,
#  'means': 687,
#  'greatest': 688,
#  'monster': 689,
#  'imagine': 690,
#  'material': 691,
#  'rock': 692,
#  'feels': 693,
#  'nearly': 694,
#  'lady': 695,
#  'deal': 696,
#  'tale': 697,
#  'realistic': 698,
#  'viewers': 699,
#  'working': 700,
#  'straight': 701,
#  'near': 702,
#  'general': 703,
#  'famous': 704,
#  'fantastic': 705,
#  'using': 706,
#  'okay': 707,
#  'elements': 708,
#  'class': 709,
#  'avoid': 710,
#  'check': 711,
#  'points': 712,
#  'kept': 713,
#  'dog': 714,
#  'period': 715,
#  'brought': 716,
#  'move': 717,
#  'begins': 718,
#  'feature': 719,
#  'tom': 720,
#  'paul': 721,
#  'form': 722,
#  'believable': 723,
#  'america': 724,
#  'dr': 725,
#  'forget': 726,
#  'eventually': 727,
#  'animation': 728,
#  'learn': 729,
#  'its': 730,
#  'hear': 731,
#  'leads': 732,
#  'somehow': 733,
#  'by': 734,
#  'rent': 735,
#  'reviews': 736,
#  'wait': 737,
#  'indeed': 738,
#  'mystery': 739,
#  'surprise': 740,
#  'atmosphere': 741,
#  'b': 742,
#  'sequences': 743,
#  'most': 744,
#  'her': 745,
#  'premise': 746,
#  'eye': 747,
#  'killing': 748,
#  'particular': 749,
#  'york': 750,
#  'weak': 751,
#  'these': 752,
#  'sit': 753,
#  'doctor': 754,
#  'situation': 755,
#  'whatever': 756,
#  'figure': 757,
#  'fast': 758,
#  'truth': 759,
#  'shame': 760,
#  'season': 761,
#  'lame': 762,
#  'difficult': 763,
#  'crime': 764,
#  'decided': 765,
#  'possibly': 766,
#  'deep': 767,
#  'imdb': 768,
#  'expected': 769,
#  'red': 770,
#  'emotional': 771,
#  'unless': 772,
#  'footage': 773,
#  'lee': 774,
#  'society': 775,
#  'boys': 776,
#  'oscar': 777,
#  'follow': 778,
#  'very': 779,
#  'begin': 780,
#  'average': 781,
#  'crew': 782,
#  'romance': 783,
#  'memorable': 784,
#  'forced': 785,
#  'scifi': 786,
#  'became': 787,
#  'dance': 788,
#  'poorly': 789,
#  'leaves': 790,
#  'note': 791,
#  'credits': 792,
#  'needed': 793,
#  'here': 794,
#  'stand': 795,
#  'cheesy': 796,
#  'screenplay': 797,
#  'nature': 798,
#  'question': 799,
#  'third': 800,
#  'otherwise': 801,
#  'sexual': 802,
#  'personal': 803,
#  'beauty': 804,
#  'total': 805,
#  'reading': 806,
#  'minute': 807,
#  'sounds': 808,
#  '20': 809,
#  'meet': 810,
#  'de': 811,
#  'meets': 812,
#  'result': 813,
#  'superb': 814,
#  'effect': 815,
#  'towards': 816,
#  'hands': 817,
#  'hot': 818,
#  'perfectly': 819,
#  'masterpiece': 820,
#  'weird': 821,
#  'laughs': 822,
#  'features': 823,
#  'open': 824,
#  'earlier': 825,
#  'interested': 826,
#  'western': 827,
#  'plus': 828,
#  'previous': 829,
#  'comment': 830,
#  'write': 831,
#  'gay': 832,
#  'crazy': 833,
#  'island': 834,
#  'mark': 835,
#  'male': 836,
#  'battle': 837,
#  'keeps': 838,
#  'setting': 839,
#  'background': 840,
#  'street': 841,
#  'realize': 842,
#  'disney': 843,
#  'brings': 844,
#  'filmmakers': 845,
#  'admit': 846,
#  'inside': 847,
#  'stage': 848,
#  'mess': 849,
#  'box': 850,
#  'unique': 851,
#  'quickly': 852,
#  'copy': 853,
#  'or': 854,
#  'incredibly': 855,
#  'worked': 856,
#  'plenty': 857,
#  'older': 858,
#  'fairly': 859,
#  'remake': 860,
#  'development': 861,
#  'powerful': 862,
#  'japanese': 863,
#  'baby': 864,
#  'joke': 865,
#  'dumb': 866,
#  'wasted': 867,
#  'air': 868,
#  'appear': 869,
#  'free': 870,
#  'ask': 871,
#  'badly': 872,
#  'business': 873,
#  'directing': 874,
#  'dramatic': 875,
#  '80': 876,
#  'match': 877,
#  'leading': 878,
#  'joe': 879,
#  'spent': 880,
#  'writers': 881,
#  'water': 882,
#  'following': 883,
#  'creepy': 884,
#  'bill': 885,
#  'portrayed': 886,
#  'acted': 887,
#  'deserves': 888,
#  'outside': 889,
#  'cop': 890,
#  'agree': 891,
#  'girlfriend': 892,
#  'fighting': 893,
#  'various': 894,
#  'apart': 895,
#  'pay': 896,
#  'rich': 897,
#  'fails': 898,
#  'la': 899,
#  'william': 900,
#  'success': 901,
#  'reasons': 902,
#  'front': 903,
#  'forward': 904,
#  'directors': 905,
#  'unlike': 906,
#  'clever': 907,
#  'fire': 908,
#  'escape': 909,
#  'zombie': 910,
#  'dream': 911,
#  'manages': 912,
#  'present': 913,
#  'create': 914,
#  'caught': 915,
#  'spoilers': 916,
#  'cover': 917,
#  'twist': 918,
#  'party': 919,
#  'plain': 920,
#  'return': 921,
#  'meant': 922,
#  'missing': 923,
#  'attempts': 924,
#  'ended': 925,
#  'expecting': 926,
#  'members': 927,
#  'potential': 928,
#  'political': 929,
#  'hardly': 930,
#  'secret': 931,
#  'large': 932,
#  'recently': 933,
#  'break': 934,
#  'villain': 935,
#  'odd': 936,
#  'pure': 937,
#  'ideas': 938,
#  'cute': 939,
#  'created': 940,
#  'gun': 941,
#  'telling': 942,
#  'casting': 943,
#  'waiting': 944,
#  'public': 945,
#  'company': 946,
#  'cartoon': 947,
#  'german': 948,
#  'pace': 949,
#  'incredible': 950,
#  'missed': 951,
#  'talented': 952,
#  'laughing': 953,
#  'era': 954,
#  'cause': 955,
#  'scott': 956,
#  'list': 957,
#  'slightly': 958,
#  'neither': 959,
#  'van': 960,
#  'entirely': 961,
#  'hold': 962,
#  'fantasy': 963,
#  'popular': 964,
#  'state': 965,
#  'portrayal': 966,
#  'train': 967,
#  'visual': 968,
#  'familiar': 969,
#  'considering': 970,
#  'mentioned': 971,
#  'nudity': 972,
#  'only': 973,
#  'sadly': 974,
#  'convincing': 975,
#  'sees': 976,
#  'credit': 977,
#  'married': 978,
#  'speak': 979,
#  'follows': 980,
#  'tension': 981,
#  'flat': 982,
#  'moves': 983,
#  'intelligent': 984,
#  'wrote': 985,
#  'uses': 986,
#  'alive': 987,
#  'decides': 988,
#  'jane': 989,
#  'bored': 990,
#  'language': 991,
#  'died': 992,
#  'fit': 993,
#  'produced': 994,
#  'italian': 995,
#  'rate': 996,
#  'trouble': 997,
#  'suddenly': 998,
#  'amount': 999,
#  'band': 1000,
#  ...}

# %%
df['review'][3]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
text = df['review'][3]

# %%
tokens = word_tokenize(text)
translator = str.maketrans('', '', punctuation)
tokens = [w.translate(translator) for w in tokens]
tokens = [w for w in tokens if not w in stop_words]
text = ' '.join(tokens)

# %%
text
# Out:
# 'Basically family little boy  Jake  thinks zombie closet  parents fighting time  br    br   This movie slower soap opera  suddenly  Jake decides become Rambo kill zombie  br    br   OK  first going make film must Decide thriller drama  As drama movie watchable  Parents divorcing  arguing like real life  And Jake closet totally ruins film  I expected see BOOGEYMAN similar movie  instead watched drama meaningless thriller spots  br    br   3 10 well playing parents  descent dialogs  As shots Jake  ignore '

# %%
text = tokenizer.texts_to_sequences([text])[0]
text
# Out:
# [582,
#  142,
#  48,
#  328,
#  3114,
#  1135,
#  910,
#  4244,
#  661,
#  893,
#  14,
#  1,
#  1,
#  10,
#  4,
#  8370,
#  1868,
#  1207,
#  998,
#  3114,
#  988,
#  335,
#  5949,
#  414,
#  910,
#  1,
#  1,
#  470,
#  26,
#  81,
#  29,
#  5,
#  120,
#  1040,
#  676,
#  368,
#  110,
#  368,
#  4,
#  1666,
#  661,
#  25388,
#  6807,
#  8,
#  68,
#  50,
#  34,
#  3114,
#  4244,
#  361,
#  3943,
#  5,
#  2,
#  769,
#  17,
#  9935,
#  639,
#  4,
#  206,
#  202,
#  368,
#  3587,
#  676,
#  3347,
#  1,
#  1,
#  348,
#  200,
#  18,
#  306,
#  661,
#  4631,
#  3260,
#  110,
#  539,
#  3114,
#  2651]

# %%
text = pad_sequences([text], maxlen=max_len, padding='post')
text
# Out:
# array([[582, 142,  48, ...,   0,   0,   0]])

# %%
text.shape
# Out:
# (1, 1824)

# %%
model.predict(text)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[1.3217071e-09]], dtype=float32)

# %%
pred = model.predict(text)
if float(pred) > 0.5:
    print('Positive')
else:
    print('Negative')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Negative
